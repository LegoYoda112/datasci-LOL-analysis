# %% [markdown]
# Helper functions for investigating match data

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# !ls data
# Out:
# _columns.csv
# bans.csv
# gold.csv
# kills.csv
# LeagueofLegends.csv
# matchinfo.csv
# monsters.csv
# structures.csv

# %%
bans = pd.read_csv("data/bans.csv")
gold = pd.read_csv("data/gold.csv")
kills = pd.read_csv("data/kills.csv")
LOL = pd.read_csv("data/LeagueofLegends.csv")
matchinfo = pd.read_csv("data/matchinfo.csv")
monsters = pd.read_csv("data/matchinfo.csv")
structures = pd.read_csv("data/structures.csv")

# %%
match_a = match(matchinfo['Address'][4])
match_a.kills()
# Out:
#                                                  Address    Team    Time  \
# 58     http://matchhistory.na.leagueoflegends.com/en/...  bKills  11.438
# 59     http://matchhistory.na.leagueoflegends.com/en/...  bKills  24.766
# 60     http://matchhistory.na.leagueoflegends.com/en/...  bKills  24.844
# 61     http://matchhistory.na.leagueoflegends.com/en/...  bKills  25.231
# 62     http://matchhistory.na.leagueoflegends.com/en/...  bKills  25.251
# 63     http://matchhistory.na.leagueoflegends.com/en/...  bKills  25.289
# 64     http://matchhistory.na.leagueoflegends.com/en/...  bKills  26.685
# 65     http://matchhistory.na.leagueoflegends.com/en/...  bKills  26.719
# 66     http://matchhistory.na.leagueoflegends.com/en/...  bKills  28.002
# 67     http://matchhistory.na.leagueoflegends.com/en/...  bKills  28.155
# 68     http://matchhistory.na.leagueoflegends.com/en/...  bKills  28.912
# 69     http://matchhistory.na.leagueoflegends.com/en/...  bKills  28.951
# 70     http://matchhistory.na.leagueoflegends.com/en/...  bKills  29.653
# 71     http://matchhistory.na.leagueoflegends.com/en/...  bKills  29.755
# 72     http://matchhistory.na.leagueoflegends.com/en/...  bKills  31.891
# 73     http://matchhistory.na.leagueoflegends.com/en/...  bKills  31.932
# 74     http://matchhistory.na.leagueoflegends.com/en/...  bKills  31.956
# 75     http://matchhistory.na.leagueoflegends.com/en/...  bKills  31.994
# 76     http://matchhistory.na.leagueoflegends.com/en/...  bKills  32.092
# 77     http://matchhistory.na.leagueoflegends.com/en/...  bKills  34.005
# 78     http://matchhistory.na.leagueoflegends.com/en/...  bKills  34.391
# 79     http://matchhistory.na.leagueoflegends.com/en/...  bKills  34.416
# 98389  http://matchhistory.na.leagueoflegends.com/en/...  rKills  11.988
# 98390  http://matchhistory.na.leagueoflegends.com/en/...  rKills  21.451
# 98391  http://matchhistory.na.leagueoflegends.com/en/...  rKills  21.636
# 98392  http://matchhistory.na.leagueoflegends.com/en/...  rKills  24.873
# 98393  http://matchhistory.na.leagueoflegends.com/en/...  rKills  25.108
# 98394  http://matchhistory.na.leagueoflegends.com/en/...  rKills  25.219
# 98395  http://matchhistory.na.leagueoflegends.com/en/...  rKills  26.804
# 98396  http://matchhistory.na.leagueoflegends.com/en/...  rKills  28.986
# 98397  http://matchhistory.na.leagueoflegends.com/en/...  rKills  29.800
# 98398  http://matchhistory.na.leagueoflegends.com/en/...  rKills  31.222
#
#                 Victim           Killer        Assist_1         Assist_2  \
# 58            T8 Dodo8   CLG Doublelift     CLG Xmithie     CLG aphromoo
# 59            T8 Dodo8      CLG Xmithie       CLG Benny         CLG Link
# 60        T8 Porpoise8   CLG Doublelift       CLG Benny      CLG Xmithie
# 61         T8 Slooshi8   CLG Doublelift        CLG Link     CLG aphromoo
# 62     T8 Maplestreet8     CLG aphromoo       CLG Benny         CLG Link
# 63      T8 CaliTrlolz8   CLG Doublelift       CLG Benny         CLG Link
# 64      T8 CaliTrlolz8   CLG Doublelift       CLG Benny      CLG Xmithie
# 65         T8 Slooshi8   CLG Doublelift       CLG Benny      CLG Xmithie
# 66            T8 Dodo8         CLG Link       CLG Benny      CLG Xmithie
# 67      T8 CaliTrlolz8         CLG Link       CLG Benny      CLG Xmithie
# 68        T8 Porpoise8         CLG Link       CLG Benny      CLG Xmithie
# 69         T8 Slooshi8         CLG Link     CLG Xmithie   CLG Doublelift
# 70     T8 Maplestreet8         CLG Link             NaN              NaN
# 71            T8 Dodo8        CLG Benny     CLG Xmithie     CLG aphromoo
# 72            T8 Dodo8         CLG Link     CLG Xmithie     CLG aphromoo
# 73     T8 Maplestreet8      CLG Xmithie       CLG Benny         CLG Link
# 74         T8 Slooshi8         CLG Link       CLG Benny      CLG Xmithie
# 75        T8 Porpoise8         CLG Link       CLG Benny      CLG Xmithie
# 76      T8 CaliTrlolz8        CLG Benny     CLG Xmithie         CLG Link
# 77        T8 Porpoise8         CLG Link       CLG Benny      CLG Xmithie
# 78            T8 Dodo8   CLG Doublelift       CLG Benny      CLG Xmithie
# 79         T8 Slooshi8      CLG Xmithie        CLG Link     CLG aphromoo
# 98389   CLG Doublelift     T8 Porpoise8     T8 Slooshi8  T8 Maplestreet8
# 98390      CLG Xmithie   T8 CaliTrlolz8    T8 Porpoise8      T8 Slooshi8
# 98391        CLG Benny   T8 CaliTrlolz8    T8 Porpoise8      T8 Slooshi8
# 98392      CLG Xmithie  T8 Maplestreet8  T8 CaliTrlolz8     T8 Porpoise8
# 98393        CLG Benny  T8 Maplestreet8  T8 CaliTrlolz8      T8 Slooshi8
# 98394         CLG Link  T8 Maplestreet8  T8 CaliTrlolz8      T8 Slooshi8
# 98395         CLG Link   T8 CaliTrlolz8     T8 Slooshi8         T8 Dodo8
# 98396   CLG Doublelift   T8 CaliTrlolz8    T8 Porpoise8      T8 Slooshi8
# 98397         CLG Link   T8 CaliTrlolz8    T8 Porpoise8  T8 Maplestreet8
# 98398   CLG Doublelift     T8 Porpoise8     T8 Slooshi8  T8 Maplestreet8
#
#               Assist_3      Assist_4  x_pos  y_pos
# 58                 NaN           NaN  14026   4726
# 59      CLG Doublelift  CLG aphromoo  10966  10414
# 60            CLG Link  CLG aphromoo  11185   9756
# 61                 NaN           NaN  12142   8621
# 62      CLG Doublelift           NaN  12264   8276
# 63        CLG aphromoo           NaN  12058   7682
# 64            CLG Link  CLG aphromoo   7276   9128
# 65        CLG aphromoo           NaN   8768   9251
# 66        CLG aphromoo           NaN   7694   8736
# 67      CLG Doublelift  CLG aphromoo   8565   8050
# 68      CLG Doublelift  CLG aphromoo   9854   8054
# 69        CLG aphromoo           NaN  10715   7608
# 70                 NaN           NaN   9606   6128
# 71                 NaN           NaN  11055   4807
# 72                 NaN           NaN   5010   6109
# 73        CLG aphromoo           NaN   5222   6172
# 74        CLG aphromoo           NaN   5466   6268
# 75        CLG aphromoo           NaN   4926   6099
# 76        CLG aphromoo           NaN   3828   6164
# 77      CLG Doublelift  CLG aphromoo  12998  10601
# 78            CLG Link  CLG aphromoo  12734  12630
# 79                 NaN           NaN  12918  12872
# 98389              NaN           NaN  11070   1071
# 98390  T8 Maplestreet8           NaN  11024   3870
# 98391  T8 Maplestreet8      T8 Dodo8  10847   3283
# 98392      T8 Slooshi8           NaN  11049  10175
# 98393              NaN           NaN  12077   8927
# 98394              NaN           NaN  12160   8296
# 98395              NaN           NaN   8692   8481
# 98396         T8 Dodo8           NaN  11032   7579
# 98397         T8 Dodo8           NaN   8520   6536
# 98398         T8 Dodo8           NaN   4342   5867

# %%
bans.loc[bans['Address'] == match_a.address]
# Out:
#                                                 Address      Team     ban_1  \
# 0     http://matchhistory.na.leagueoflegends.com/en/...  blueBans    Rumble
# 7620  http://matchhistory.na.leagueoflegends.com/en/...   redBans  Tristana
#
#          ban_2      ban_3 ban_4 ban_5
# 0     Kassadin  Lissandra   NaN   NaN
# 7620   Leblanc    Nidalee   NaN   NaN

# %%
class match:
    def __init__(self, address):
        self.address = address
    
    def info(self):
        return matchinfo.loc[matchinfo['Address'] == self.address]
    
    def bans(self):
        return bans.loc[bans['Address'] == self.address]
    
    # ===== GOLD =====
    def gold(self):
        return gold.loc[gold['Address'] == self.address]
    
    def gold_type(self, gold_type):
        return gold.loc[(gold['Address'] == self.address) & (gold['Type'] == gold_type)]
    
    def gold_types(self):
        return list(self.gold()['Type'])
    
    def kills(self):
        return kills.loc[kills['Address'] == self.address]
    
    def blue_kills(self):
        self_kills = self.kills()
        return self_kills.loc[self_kills['Team'] == 'bKills']
    
    def blue_kills(self):
        self_kills = self.kills()
        return self_kills.loc[self_kills['Team'] == 'rKills']
    
    def monsters(self):
        return monsters.loc[monsters['Address'] == self.address]
    
    def structures(self):
        return structures.loc[structures['Address'] == self.address]
    
    def blue_structures(self):
        self_structures = self.structures()
        return self_structures.loc[(self_structures['Team'] == 'bTowers') | (self_structures['Team'] == 'bInhibs')]
    
    def red_structures(self):
        self_structures = self.structures()
        return self_structures.loc[(self_structures['Team'] == 'rTowers') | (self_structures['Team'] == 'rInhibs')]
